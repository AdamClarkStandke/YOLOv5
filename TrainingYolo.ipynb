# %% [markdown]
# <a href="https://colab.research.google.com/github/aCStandke/Object-Detection/blob/main/TrainingYolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
# This notebook was set up to train a YOLOv5s model on a custom dataset of raccoons. The dataset was annotated by Dat Tran as found in his medium article titled: How to train your own Object Detector with TensorFlow's Object Dector API as found @ https://towardsdatascience.com/how-to-train-your-own-object-detector-with-tensorflows-object-detector-api-bec72ecfe1d9. Instead of Tensorflow, the YOLOv5 model was fetched from github from  ultralytics repository.

# %%
#clone YOLOv5 and 
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12822, done.
# remote: Total 12822 (delta 0), reused 0 (delta 0), pack-reused 12822
# Receiving objects: 100% (12822/12822), 11.75 MiB | 11.77 MiB/s, done.
# Resolving deltas: 100% (8913/8913), done.
# /content/yolov5
#      |████████████████████████████████| 596 kB 4.3 MB/s

# %% [markdown]
# # Virtural Machine
#
# Using colabs generic option, was able to get a vm with 12 MB of Ram and a Tesla K80 graphics card

# %%
import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.10.0+cu111 (Tesla K80)

# %% [markdown]
# # Training YOLOv5s
#
# Yolo was trained for 200 epochs with a batch size of 10 and image size of 640. After pre-processing the orginal dataset to work for the model, only single raccoons in the image were used. Below you can find the hyperparameters, the model architecture of 270 layers and 7,022,326 parameters. Both the training and validation set were the same (I know, but I have limited time lol).
#
# # Results
#
#
# *   Precision:
# *   Recall:
# *   mAP @.05:

# %%
# !python3 train.py --img 640 --batch 10 --epochs 200 --data ../drive/MyDrive/Datasets/config_one.yaml --weights ../drive/MyDrive/Datasets/yolov5s.pt
# Out:
# ...
# train: weights=../drive/MyDrive/Datasets/yolov5s.pt, cfg=, data=../drive/MyDrive/Datasets/config_one.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=10, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-132-g014acde torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
# # Start tensorboard
# # Launch after you have started training
# # logs save in the folder "runs"
# %load_ext tensorboard
# %tensorboard --logdir runs

# %% [markdown]
# # Inference
#
# To test the inference of the trained model a simple video of a raccoon was aquired. The reslts of which are shown below

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --source /content/drive/MyDrive/Datasets/raccoon_dataset/test/
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/Datasets/raccoon_dataset/test/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-132-g014acde torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/966) /content/drive/MyDrive/Datasets/raccoon_dataset/test/racoon.mp4: 384x640 Done. (0.027s)
# video 1/1 (2/966) /content/drive/MyDrive/Datasets/raccoon_dataset/test/racoon.mp4: 384x640 Done. (0.027s)
# video 1/1 (3/966) /content/drive/MyDrive/Datasets/raccoon_dataset/test/racoon.mp4: 384x640 Done. (0.027s)
# ...

# %% [markdown]
# # Saving Trained weights on Raccoon Dataset

# %%
# !cp /content/yolov5/runs/train/exp/weights/best.pt /content/drive/MyDrive/
