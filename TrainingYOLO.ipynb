# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import torch
import utils
import os
from IPython.display import Image

# %%
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v6.1-119-gf1112c7 torch 1.10.2+cu102 CPU
# Setup complete ✅ (2 CPUs, 2.7 GB RAM, 15.6/18.6 GB disk)

# %%
# !python3 detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source /mnt/chromeos/GoogleDrive/MyDrive/Datasets/baby.PNG
display.Image(filename='runs/detect/exp5/baby.PNG', width=325)
# Out:
# detect: weights=['yolov5s.pt'], source=/mnt/chromeos/GoogleDrive/MyDrive/Datasets/baby.PNG, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-119-gf1112c7 torch 1.10.2+cu102 CPU
#
# Fusing layers...
# [W NNPACK.cpp:79] Could not initialize NNPACK! Reason: Unsupported hardware.
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.5 GFLOPs
# image 1/1 /mnt/chromeos/GoogleDrive/MyDrive/Datasets/baby.PNG: 608x640 2 persons, 1 potted plant, Done. (2.867s)
# Speed: 18.8ms pre-process, 2866.9ms inference, 9.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp6

# %%
# !python3 Faster\ R-CNN.py
# Out:
# [W NNPACK.cpp:79] Could not initialize NNPACK! Reason: Unsupported hardware.

# %%
img = Image(filename='Faster R-CNN.png')
img
